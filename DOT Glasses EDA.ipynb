# %% [markdown]
# # EDA is an essential part in all machine learning works to know the trend in data and features so that we can improve model #performance by choosing features according to the insights gained from EDA
#
# # In this step, use scatter plots to see how the target variable is related to each feature, use heatmap to see correlation and # # also see the distribution of the sales column

# %% [markdown]
# <h2>Importing Libraries </h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
import pylab

# %% [markdown]
# <h2>Data Inspection</h2>

# %%
df = pd.read_csv('Cleaned_advertising.csv',index_col=[0])

# %%
df.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
# statistical description of data
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  198.000000  200.000000
# mean   147.042500   23.264000   29.777273   15.130500
# std     85.854236   14.846809   20.446303    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.650000   11.000000
# 50%    149.750000   22.900000   25.600000   16.000000
# 75%    218.825000   36.525000   44.050000   19.050000
# max    296.400000   49.600000   89.400000   27.000000

# %% [markdown]
# <h5>There is huge spending on TV advertisement on an average 147,000 dollars and minimum on radio of 23,000 dollars</h5>

# %%
df.info() # for concise summary of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  198 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %% [markdown]
# VISUALIZE DATASET

# %%
sns.pairplot(df)

# %% [markdown]
# <h4>
# Target Sales is directly correlated with TV, little with Radio but there is no correlation with Newspaper
#
# There is no correlation seems between all features.</h4>

# %%
fig, axs = plt.subplots(1, 3)
df.plot(kind='scatter', x='TV', y='Sales', ax=axs[0], figsize=(16, 7))
df.plot(kind='scatter', x='Radio', y='Sales', ax=axs[1])
df.plot(kind='scatter', x='Newspaper', y='Sales', ax=axs[2])
# Out:
# <AxesSubplot: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# <h4>As is visible from the pairplot and the heatmap, the variable TV seems to be most correlated with Sales</h4>
